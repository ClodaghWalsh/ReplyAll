# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
from itertools import chain

# %% [markdown]
# ## Get Episode URLs

# %%
base_url = 'https://gimletmedia.com/shows/reply-all/episodes'

response = requests.get(base_url)

page = response.text

soup = BeautifulSoup(page, "html.parser")

# %%
def getEpisodes(soup):
    """
    grabs unique episode links from ReplyAll episodes list
    """
    
    table = soup.findAll('div', {'class' : 'title-section'})
    
    episodes = []
    for element in table:
        
        episodes.append(element.find('a')['href'])
    
    return episodes

# %%
episode_links = getEpisodes(soup)

# %%
episode_links
# Out:
# ['/shows/reply-all/wbhawn/96-the-secret-life-of-alex-goldman',
#  '/shows/reply-all/2oh5o6/128-the-crime-machine-part-ii',
#  '/shows/reply-all/76h967/127-the-crime-machine-part-i',
#  '/shows/reply-all/emh82l/120-invcel',
#  '/shows/reply-all/xjhx3l/146-summer-hotline',
#  '/shows/reply-all/rnhzlo/145-louder',
#  '/shows/reply-all/6nhgol/144-dark-pattern',
#  '/shows/reply-all/76hdrj/143-permanent-record',
#  '/shows/reply-all/gmhr36/142-we-didnt-start-the-fire',
#  '/shows/reply-all/39hrwn/41-what-it-looks-like',
#  '/shows/reply-all/z3hgd2/141-adam-pisces-and-the-2-coke',
#  '/shows/reply-all/brh8jm/140-the-roman-mars-mazda-virus',
#  '/shows/reply-all/5whgo2/139-the-reply-all-hotline',
#  '/shows/reply-all/j4h6jd/138-the-great-momo-panic',
#  '/shows/reply-all/94hord/137-fools-trade',
#  '/shows/reply-all/dvhd9k/136-the-founder',
#  '/shows/reply-all/awhk76/135-robocall-bang-bang',
#  '/shows/reply-all/8wh258/134-the-year-of-the-wallop',
#  '/shows/reply-all/8who5k/133-reply-alls-2018-year-end',
#  '/shows/reply-all/wbhjwd/132-negative-mount-pleasant',
#  '/shows/reply-all/v4he8w/131-surefire-investigations',
#  '/shows/reply-all/v4he6k/130-the-snapchat-thief',
#  '/shows/reply-all/o2ho2j/129-autumn',
#  '/shows/reply-all/n8hwl7/128-the-crime-machine-part-ii',
#  '/shows/reply-all/o2hx34/127-the-crime-machine-part-i',
#  '/shows/reply-all/mehwa6/126-alex-jones-dramageddon',
#  '/shows/reply-all/llhe3j/125-all-my-pets',
#  '/shows/reply-all/brhow4/124-the-magic-store',
#  '/shows/reply-all/8whoek/123-an-ad-for-the-worst-day-of-your-life',
#  '/shows/reply-all/n8homa/122-the-qanon-code',
#  '/shows/reply-all/emhw45/121-pain-funnel',
#  '/shows/reply-all/76h59o/120-invcel',
#  '/shows/reply-all/o2ho97/119-no-more-safe-harbor',
#  '/shows/reply-all/76h5ro/118-a-pirate-in-search-of-a-judge',
#  '/shows/reply-all/dvhe3l/117-the-worlds-most-expensive-free-watch',
#  '/shows/reply-all/v4he8k/116-trust-the-process',
#  '/shows/reply-all/z3hl9r/115-the-bitcoin-hunter',
#  '/shows/reply-all/xjhewe/114-apocalypse-soon',
#  '/shows/reply-all/94hwea/113-reply-alls-year-end-extravaganza',
#  '/shows/reply-all/j4hl36/112-the-prophet',
#  '/shows/reply-all/5whmed/111-return-of-the-russian-passenger',
#  '/shows/reply-all/wbhjod/presenting-heavyweight',
#  '/shows/reply-all/brhog4/110-the-antifa-supersoldier-spectacular',
#  '/shows/reply-all/z3hlwr/109-is-facebook-spying-on-you',
#  '/shows/reply-all/39hzvw/108-the-skip-tracer-part-ii',
#  '/shows/reply-all/gmhn33/107-the-skip-tracer-part-i',
#  '/shows/reply-all/gmhn73/106-is-that-you-kd',
#  '/shows/reply-all/j4hlx6/105-at-worlds-end',
#  '/shows/reply-all/n8ho3a/104-the-case-of-the-phantom-caller',
#  '/shows/reply-all/76h5gl/103-long-distance-part-ii',
#  '/shows/reply-all/6nh3wk/102-long-distance',
#  '/shows/reply-all/rnhoaw/101-minka',
#  '/shows/reply-all/n8ho4m/100-friends-and-blasphemers',
#  '/shows/reply-all/5whmxd/99-black-hole-new-jersey',
#  '/shows/reply-all/o2ho9j/98-fog-of-covfefe',
#  '/shows/reply-all/rnhoww/97-what-kind-of-idiot-gets-phished',
#  '/shows/reply-all/dvhe6l/96-the-secret-life-of-alex-goldman',
#  '/shows/reply-all/8who3a/95-the-silence-in-the-sky',
#  '/shows/reply-all/94hw7a/94-obfuscation',
#  '/shows/reply-all/xjheve/93-beware-all',
#  '/shows/reply-all/8whoxk/92-favor-atender-the-return',
#  '/shows/reply-all/z3hler/91-the-russian-passenger',
#  '/shows/reply-all/brho54/90-matt-lieber-goes-to-dinner',
#  '/shows/reply-all/5whmjd/89-worldstar',
#  '/shows/reply-all/j4hlv6/88-second-language',
#  '/shows/reply-all/94hw4a/87-storming-the-castle',
#  '/shows/reply-all/dvhexl/86-man-of-the-people',
#  '/shows/reply-all/awhmoj/85-the-reversal',
#  '/shows/reply-all/6nh3jk/84-past-present-future-2',
#  '/shows/reply-all/rnholw/47-quit-already-rebroadcast',
#  '/shows/reply-all/emhwl5/83-voyage-into-pizzagate',
#  '/shows/reply-all/llhezj/82-hello',
#  '/shows/reply-all/76h56o/81-in-the-tall-grass',
#  '/shows/reply-all/v4hemk/80-flash',
#  '/shows/reply-all/39hz7w/29-the-takeover-rebroadcast',
#  '/shows/reply-all/llhev8/79-boy-in-photo',
#  '/shows/reply-all/o2ho87/78-very-quickly-to-the-drill',
#  '/shows/reply-all/n8ho8a/77-the-grand-tapestry-of-pepe',
#  '/shows/reply-all/mehw86/76-lost-in-a-cab',
#  '/shows/reply-all/kwhx9v/75-boy-wonder',
#  '/shows/reply-all/49hr6k/74-making-friends',
#  '/shows/reply-all/xjhe8e/73-sandbox',
#  '/shows/reply-all/wbhjgd/72-dead-is-paul',
#  '/shows/reply-all/2oh9ge/71-the-picture-taker',
#  '/shows/reply-all/brhojv/70-stolen-valor',
#  '/shows/reply-all/xjhe54/69-disappeared',
#  '/shows/reply-all/kwhxj9/68-vampire-rules',
#  '/shows/reply-all/mehw3a/67-on-the-inside-part-iv',
#  '/shows/reply-all/2oh9d3/66-on-the-inside-part-iii',
#  '/shows/reply-all/6nh3vm/65-on-the-inside-part-ii',
#  '/shows/reply-all/brho4v/64-on-the-inside',
#  '/shows/reply-all/j4hlob/63-1000-brimes',
#  '/shows/reply-all/39hz92/62-decoders',
#  '/shows/reply-all/emhwx6/61-baby-king',
#  '/shows/reply-all/39hz8w/60-a-simple-question',
#  '/shows/reply-all/llheb8/59-good-job-alex',
#  '/shows/reply-all/mehw2a/58-earth-pony',
#  '/shows/reply-all/v4he9w/57-milk-wanted',
#  '/shows/reply-all/o2ho6j/56-zardulu',
#  '/shows/reply-all/2oh9ee/55-the-line',
#  '/shows/reply-all/kwhx3v/54-apologies-to-dr-rosalind-franklin',
#  '/shows/reply-all/n8hodm/53-in-the-desert',
#  '/shows/reply-all/5whmrm/psa-hidden-trove',
#  '/shows/reply-all/76h54l/52-raising-the-bar',
#  '/shows/reply-all/kwhxw9/51-perfect-crime',
#  '/shows/reply-all/6nh34m/50-the-cathedral',
#  '/shows/reply-all/z3hln4/49-past-present-future',
#  '/shows/reply-all/49hrm3/48-i-love-you-i-loathe-you',
#  '/shows/reply-all/dvhe8r/47-quit-already',
#  '/shows/reply-all/wbhjer/46-yik-yak-returns',
#  '/shows/reply-all/dvhebr/45-the-rainbow-pug',
#  '/shows/reply-all/2oh933/44-shine-on-you-crazy-goldman',
#  '/shows/reply-all/rnhoxb/43-the-law-that-sticks',
#  '/shows/reply-all/awhmzx/42-blind-spot',
#  '/shows/reply-all/mehwba/41-what-it-looks-like',
#  '/shows/reply-all/gmhn2r/40-the-flower-child',
#  '/shows/reply-all/gmhn8r/39-reply-all-exploder',
#  '/shows/reply-all/6nh3dm/38-undo-undo-undo',
#  '/shows/reply-all/v4hezw/37-taking-power',
#  '/shows/reply-all/rnhokb/36-todays-the-day',
#  '/shows/reply-all/kwhxl9/35-one-strike',
#  '/shows/reply-all/49hr93/34-dmv-nation',
#  '/shows/reply-all/49hr33/6-this-proves-everything-the-best-hold',
#  '/shows/reply-all/2oh9w3/33-isis',
#  '/shows/reply-all/49hr8k/32-the-evilest-technology-on-earth',
#  '/shows/reply-all/llhe98/31-bonus-the-reddit-implosion-explainer',
#  '/shows/reply-all/n8ho2m/30-the-man-in-the-fbi-hat',
#  '/shows/reply-all/94hwmv/29-the-takeover',
#  '/shows/reply-all/xjhem4/28-shipped-to-timbuktu',
#  '/shows/reply-all/wbhjbr/27-the-fever',
#  '/shows/reply-all/rnho9b/26-craigslist-horsleys-list',
#  '/shows/reply-all/gmhnzr/25-favor-atender',
#  '/shows/reply-all/awhm5x/24-exit-return-part-ii',
#  '/shows/reply-all/39hzw2/23-exit-return-part-i',
#  '/shows/reply-all/n8ho4a/22-bonus-the-man-who-refused-to-email',
#  '/shows/reply-all/z3hld4/55-jennicam-revisited',
#  '/shows/reply-all/39hz62/21-hack-the-police',
#  '/shows/reply-all/awhm2j/20-i-want-to-break-free',
#  '/shows/reply-all/brho3v/19-underdog',
#  '/shows/reply-all/z3hlr4/18-silence-and-respect',
#  '/shows/reply-all/5whmom/17-the-time-traveler-and-the-hitman',
#  '/shows/reply-all/j4hljb/16-why-is-mason-reese-crying',
#  '/shows/reply-all/5whmkm/15-ive-killed-people-and-i-have-hostages',
#  '/shows/reply-all/94hw2v/14-the-art-of-making-and-fixing-mistakes',
#  '/shows/reply-all/v4herw/13-love-is-lies',
#  '/shows/reply-all/94hw3v/1-an-app-sends-a-stranger-to-say-i-love',
#  '/shows/reply-all/llhel8/12-back-end-trouble',
#  '/shows/reply-all/kwhxjv/11-did-errol-morris-brother-invent-email',
#  '/shows/reply-all/8whoda/10-the-french-connection',
#  '/shows/reply-all/dvhezr/9-the-writing-on-the-wall',
#  '/shows/reply-all/j4hlzb/8-anxiety-box',
#  '/shows/reply-all/o2horj/7-this-website-is-for-sale',
#  '/shows/reply-all/xjhed4/6-this-proves-everything',
#  '/shows/reply-all/8whoja/5-jennicam',
#  '/shows/reply-all/76h5zl/4-follow-the-money',
#  '/shows/reply-all/awhmex/3-we-know-what-you-did',
#  '/shows/reply-all/wbhjrr/1-a-stranger-says-i-love-you',
#  '/shows/reply-all/emhwz6/2-the-secret-gruesome-internet-for',
#  '/shows/reply-all/emhwo6/reply-all-mic-test']

# %%
len(episode_links) #need to remove rebroadcasts/gimlet podcast announcements
# Out:
# 159

# %%
#remove gimlet show updates
pattern = '\/shows\/reply-all\/\w*\/[0-9]+'
episode_numbers = []

for episode in episode_links:
    if re.match(pattern, episode):
        episode_numbers.append(episode)

# %%
episode_numbers
# Out:
# ['/shows/reply-all/xjhx3l/146-summer-hotline',
#  '/shows/reply-all/rnhzlo/145-louder',
#  '/shows/reply-all/6nhgol/144-dark-pattern',
#  '/shows/reply-all/76hdrj/143-permanent-record',
#  '/shows/reply-all/gmhr36/142-we-didnt-start-the-fire',
#  '/shows/reply-all/z3hgd2/141-adam-pisces-and-the-2-coke',
#  '/shows/reply-all/brh8jm/140-the-roman-mars-mazda-virus',
#  '/shows/reply-all/5whgo2/139-the-reply-all-hotline',
#  '/shows/reply-all/j4h6jd/138-the-great-momo-panic',
#  '/shows/reply-all/94hord/137-fools-trade',
#  '/shows/reply-all/dvhd9k/136-the-founder',
#  '/shows/reply-all/awhk76/135-robocall-bang-bang',
#  '/shows/reply-all/8wh258/134-the-year-of-the-wallop',
#  '/shows/reply-all/8who5k/133-reply-alls-2018-year-end',
#  '/shows/reply-all/wbhjwd/132-negative-mount-pleasant',
#  '/shows/reply-all/v4he8w/131-surefire-investigations',
#  '/shows/reply-all/v4he6k/130-the-snapchat-thief',
#  '/shows/reply-all/o2ho2j/129-autumn',
#  '/shows/reply-all/n8hwl7/128-the-crime-machine-part-ii',
#  '/shows/reply-all/o2hx34/127-the-crime-machine-part-i',
#  '/shows/reply-all/mehwa6/126-alex-jones-dramageddon',
#  '/shows/reply-all/llhe3j/125-all-my-pets',
#  '/shows/reply-all/brhow4/124-the-magic-store',
#  '/shows/reply-all/8whoek/123-an-ad-for-the-worst-day-of-your-life',
#  '/shows/reply-all/n8homa/122-the-qanon-code',
#  '/shows/reply-all/emhw45/121-pain-funnel',
#  '/shows/reply-all/76h59o/120-invcel',
#  '/shows/reply-all/o2ho97/119-no-more-safe-harbor',
#  '/shows/reply-all/76h5ro/118-a-pirate-in-search-of-a-judge',
#  '/shows/reply-all/dvhe3l/117-the-worlds-most-expensive-free-watch',
#  '/shows/reply-all/v4he8k/116-trust-the-process',
#  '/shows/reply-all/z3hl9r/115-the-bitcoin-hunter',
#  '/shows/reply-all/xjhewe/114-apocalypse-soon',
#  '/shows/reply-all/94hwea/113-reply-alls-year-end-extravaganza',
#  '/shows/reply-all/j4hl36/112-the-prophet',
#  '/shows/reply-all/5whmed/111-return-of-the-russian-passenger',
#  '/shows/reply-all/brhog4/110-the-antifa-supersoldier-spectacular',
#  '/shows/reply-all/z3hlwr/109-is-facebook-spying-on-you',
#  '/shows/reply-all/39hzvw/108-the-skip-tracer-part-ii',
#  '/shows/reply-all/gmhn33/107-the-skip-tracer-part-i',
#  '/shows/reply-all/gmhn73/106-is-that-you-kd',
#  '/shows/reply-all/j4hlx6/105-at-worlds-end',
#  '/shows/reply-all/n8ho3a/104-the-case-of-the-phantom-caller',
#  '/shows/reply-all/76h5gl/103-long-distance-part-ii',
#  '/shows/reply-all/6nh3wk/102-long-distance',
#  '/shows/reply-all/rnhoaw/101-minka',
#  '/shows/reply-all/n8ho4m/100-friends-and-blasphemers',
#  '/shows/reply-all/5whmxd/99-black-hole-new-jersey',
#  '/shows/reply-all/o2ho9j/98-fog-of-covfefe',
#  '/shows/reply-all/rnhoww/97-what-kind-of-idiot-gets-phished',
#  '/shows/reply-all/dvhe6l/96-the-secret-life-of-alex-goldman',
#  '/shows/reply-all/8who3a/95-the-silence-in-the-sky',
#  '/shows/reply-all/94hw7a/94-obfuscation',
#  '/shows/reply-all/xjheve/93-beware-all',
#  '/shows/reply-all/8whoxk/92-favor-atender-the-return',
#  '/shows/reply-all/z3hler/91-the-russian-passenger',
#  '/shows/reply-all/brho54/90-matt-lieber-goes-to-dinner',
#  '/shows/reply-all/5whmjd/89-worldstar',
#  '/shows/reply-all/j4hlv6/88-second-language',
#  '/shows/reply-all/94hw4a/87-storming-the-castle',
#  '/shows/reply-all/dvhexl/86-man-of-the-people',
#  '/shows/reply-all/awhmoj/85-the-reversal',
#  '/shows/reply-all/6nh3jk/84-past-present-future-2',
#  '/shows/reply-all/emhwl5/83-voyage-into-pizzagate',
#  '/shows/reply-all/llhezj/82-hello',
#  '/shows/reply-all/76h56o/81-in-the-tall-grass',
#  '/shows/reply-all/v4hemk/80-flash',
#  '/shows/reply-all/llhev8/79-boy-in-photo',
#  '/shows/reply-all/o2ho87/78-very-quickly-to-the-drill',
#  '/shows/reply-all/n8ho8a/77-the-grand-tapestry-of-pepe',
#  '/shows/reply-all/mehw86/76-lost-in-a-cab',
#  '/shows/reply-all/kwhx9v/75-boy-wonder',
#  '/shows/reply-all/49hr6k/74-making-friends',
#  '/shows/reply-all/xjhe8e/73-sandbox',
#  '/shows/reply-all/wbhjgd/72-dead-is-paul',
#  '/shows/reply-all/2oh9ge/71-the-picture-taker',
#  '/shows/reply-all/brhojv/70-stolen-valor',
#  '/shows/reply-all/xjhe54/69-disappeared',
#  '/shows/reply-all/kwhxj9/68-vampire-rules',
#  '/shows/reply-all/mehw3a/67-on-the-inside-part-iv',
#  '/shows/reply-all/2oh9d3/66-on-the-inside-part-iii',
#  '/shows/reply-all/6nh3vm/65-on-the-inside-part-ii',
#  '/shows/reply-all/brho4v/64-on-the-inside',
#  '/shows/reply-all/j4hlob/63-1000-brimes',
#  '/shows/reply-all/39hz92/62-decoders',
#  '/shows/reply-all/emhwx6/61-baby-king',
#  '/shows/reply-all/39hz8w/60-a-simple-question',
#  '/shows/reply-all/llheb8/59-good-job-alex',
#  '/shows/reply-all/mehw2a/58-earth-pony',
#  '/shows/reply-all/v4he9w/57-milk-wanted',
#  '/shows/reply-all/o2ho6j/56-zardulu',
#  '/shows/reply-all/2oh9ee/55-the-line',
#  '/shows/reply-all/kwhx3v/54-apologies-to-dr-rosalind-franklin',
#  '/shows/reply-all/n8hodm/53-in-the-desert',
#  '/shows/reply-all/76h54l/52-raising-the-bar',
#  '/shows/reply-all/kwhxw9/51-perfect-crime',
#  '/shows/reply-all/6nh34m/50-the-cathedral',
#  '/shows/reply-all/z3hln4/49-past-present-future',
#  '/shows/reply-all/49hrm3/48-i-love-you-i-loathe-you',
#  '/shows/reply-all/dvhe8r/47-quit-already',
#  '/shows/reply-all/wbhjer/46-yik-yak-returns',
#  '/shows/reply-all/dvhebr/45-the-rainbow-pug',
#  '/shows/reply-all/2oh933/44-shine-on-you-crazy-goldman',
#  '/shows/reply-all/rnhoxb/43-the-law-that-sticks',
#  '/shows/reply-all/awhmzx/42-blind-spot',
#  '/shows/reply-all/mehwba/41-what-it-looks-like',
#  '/shows/reply-all/gmhn2r/40-the-flower-child',
#  '/shows/reply-all/6nh3dm/38-undo-undo-undo',
#  '/shows/reply-all/v4hezw/37-taking-power',
#  '/shows/reply-all/rnhokb/36-todays-the-day',
#  '/shows/reply-all/kwhxl9/35-one-strike',
#  '/shows/reply-all/49hr93/34-dmv-nation',
#  '/shows/reply-all/49hr33/6-this-proves-everything-the-best-hold',
#  '/shows/reply-all/2oh9w3/33-isis',
#  '/shows/reply-all/49hr8k/32-the-evilest-technology-on-earth',
#  '/shows/reply-all/llhe98/31-bonus-the-reddit-implosion-explainer',
#  '/shows/reply-all/n8ho2m/30-the-man-in-the-fbi-hat',
#  '/shows/reply-all/94hwmv/29-the-takeover',
#  '/shows/reply-all/xjhem4/28-shipped-to-timbuktu',
#  '/shows/reply-all/wbhjbr/27-the-fever',
#  '/shows/reply-all/rnho9b/26-craigslist-horsleys-list',
#  '/shows/reply-all/gmhnzr/25-favor-atender',
#  '/shows/reply-all/awhm5x/24-exit-return-part-ii',
#  '/shows/reply-all/39hzw2/23-exit-return-part-i',
#  '/shows/reply-all/n8ho4a/22-bonus-the-man-who-refused-to-email',
#  '/shows/reply-all/39hz62/21-hack-the-police',
#  '/shows/reply-all/awhm2j/20-i-want-to-break-free',
#  '/shows/reply-all/brho3v/19-underdog',
#  '/shows/reply-all/z3hlr4/18-silence-and-respect',
#  '/shows/reply-all/5whmom/17-the-time-traveler-and-the-hitman',
#  '/shows/reply-all/j4hljb/16-why-is-mason-reese-crying',
#  '/shows/reply-all/5whmkm/15-ive-killed-people-and-i-have-hostages',
#  '/shows/reply-all/94hw2v/14-the-art-of-making-and-fixing-mistakes',
#  '/shows/reply-all/v4herw/13-love-is-lies',
#  '/shows/reply-all/llhel8/12-back-end-trouble',
#  '/shows/reply-all/kwhxjv/11-did-errol-morris-brother-invent-email',
#  '/shows/reply-all/8whoda/10-the-french-connection',
#  '/shows/reply-all/dvhezr/9-the-writing-on-the-wall',
#  '/shows/reply-all/j4hlzb/8-anxiety-box',
#  '/shows/reply-all/o2horj/7-this-website-is-for-sale',
#  '/shows/reply-all/8whoja/5-jennicam',
#  '/shows/reply-all/76h5zl/4-follow-the-money',
#  '/shows/reply-all/awhmex/3-we-know-what-you-did',
#  '/shows/reply-all/emhwz6/2-the-secret-gruesome-internet-for',
#  '/shows/reply-all/wbhjrr/1-a-stranger-says-i-love-you']

# %%
len(episode_numbers)
# Out:
# 156

# %% [markdown]
# #### Some manual episode removal
# Can recreate with regex in another iteration

# %%
episode_numbers.remove('/shows/reply-all/emh82l/120-invcel')
episode_numbers.remove('/shows/reply-all/39hrwn/41-what-it-looks-like')
episode_numbers.remove('/shows/reply-all/rnholw/47-quit-already-rebroadcast')
episode_numbers.remove('/shows/reply-all/39hz7w/29-the-takeover-rebroadcast')
episode_numbers.remove('/shows/reply-all/xjhed4/6-this-proves-everything')
episode_numbers.remove('/shows/reply-all/94hw3v/1-an-app-sends-a-stranger-to-say-i-love')
episode_numbers.remove('/shows/reply-all/z3hld4/55-jennicam-revisited')
episode_numbers.remove('/shows/reply-all/gmhn8r/39-reply-all-exploder')
episode_numbers.remove('/shows/reply-all/76h967/127-the-crime-machine-part-i')
episode_numbers.remove('/shows/reply-all/2oh5o6/128-the-crime-machine-part-ii')
episode_numbers.remove('/shows/reply-all/wbhawn/96-the-secret-life-of-alex-goldman')

# %%
len(episode_numbers) #woo!
# Out:
# 145

# %% [markdown]
# ## Get Transcripts

# %%
gimlet = 'https://gimletmedia.com'

# %%
#This method gets most episodes (130). Loses episodes 65-77 
#from variation in webpage setup between episodes

def getTranscripts(url):
    
    """
    Takes in the epiosde url and scrapes trancripts 
    """
    
    r = requests.get(url)
    p = r.text
    s = BeautifulSoup(p, 'lxml')
    
    transcript_html = s.find('div', {'class': 'box transcript-box'})
    
    span_elements = transcript_html.findAll(['span', 'p'])
    
    text = ''
    
    for element in span_elements:
        text += element.text
    
    return text

# %%
def createDocuments():
    """
    format transcripts for insertion into MongoDB
    """
    
    document_list = []
    
    for episode in episode_numbers:
        url = gimlet + episode
    
        try:

            document_list.append({
                'episodeID' : episode,
                'full_trans' : getTranscripts(url),
                'by_speaker': {
                    
                    'PJ': '',
                    'Alex': ''
                }
                })

        except AttributeError:
            print(episode)
    
    return document_list

# %%
total_dictionaries = createDocuments()
# Out:
# /shows/reply-all/dvhe8r/47-quit-already

# %% [markdown]
# ## Get Speaker Names and Text

# %%
def getName(document):
    
    names = []
    clean_names = []
    
    names.append(re.findall("[A-Z ]+:", document['full_trans']))
    

    for name in names:       
        
        name = [x.replace('BREAK', '') for x in name]
        name = [x.replace('MUSIC', '') for x in name]
        name = [x.replace('CREDITS', '') for x in name]
        
        name = [x.strip() for x in name]
        
        clean_names.append(name)
    
    
    return clean_names

# %%
def getQuote(document):
    quotes = []
    
    quotes.append(re.split("[A-Z ]+:", document['full_trans']))
    
    for quote in quotes:
        quote.pop(0)
    
    return quotes

# %% [markdown]
# ### Look through all unique speakers
# to find names PJ and Alex are referred to and control for errors created by earlier RegEx name extraction

# %%
total_names = []
for document in total_dictionaries:
    name = getName(document)
    total_names += name

# %%
names_unpacked = list(chain(*total_names))

# %%
len(names_unpacked) #total number of speakers
# Out:
# 33306

# %%
names_unique = set(names_unpacked)

# %%
len(names_unique) #number of unique speakers
# Out:
# 1023

# %%
list(names_unique)[:500]
# Out:
# ['THEATER:',
#  'TOR:',
#  'NATHANIEL WAUGH:',
#  'ELLIOTT WILSON:',
#  'MARYANNE:',
#  'PM:',
#  'LINDSEY STONE:',
#  'S MANAGER:',
#  'TOR EKELAND:',
#  'ED MAGEDSON:',
#  'AARON SWARTZ:',
#  'RICHARD:',
#  'HILLARY CLINTON:',
#  'VILLAGERS:',
#  'VOICEMAIL:',
#  'MICHELLE GOMEZ:',
#  'LP:',
#  'SAMIN:',
#  'MARK FORMAN:',
#  'OTHERS:',
#  'ALEX :',
#  'PHIA:',
#  'LARGE MAN:',
#  'ANDY MILLS:',
#  'OTHER MAN:',
#  'RYAN HAGEN:',
#  'THOMAS OSCAR:',
#  'JUNIPER:',
#  'JIMMY FALLON:',
#  'VIRGIL TEXAS:',
#  'DALIS:',
#  'THEMEALEX:',
#  'JIA:',
#  'JO ROTH:',
#  'ANDY:',
#  'PROTESTER:',
#  'SYLVIA:',
#  'LUISA:',
#  'LINDA MODROWSKI:',
#  'LONNY PRICE:',
#  'KD:',
#  'DAVID SWENSON:',
#  'PETER SMITH:',
#  'KALILA HOLT:',
#  'HOWARD:',
#  'ALISA LIBBY:',
#  'ALL:',
#  'NANCY:',
#  'CAPTAIN AMERICA:',
#  'GREG KNAUSS:',
#  'VIDEO NARRATOR:',
#  'PHONE RINGSPJ:',
#  'ANDREA NOEL:',
#  'JOSEPH:',
#  'JOSH LARSON:',
#  'KIM ZETTER:',
#  'NICK:',
#  'POPE:',
#  'AUTOMATED VOICE:',
#  'SNOW PLOW SHOW:',
#  'CARL:',
#  'PJ AND ALEX BLUMBERG:',
#  'NAZANIN:',
#  'KELLY GALLAHER:',
#  'JOAN:',
#  'PETER CARROLL:',
#  'TOMMY:',
#  'AD TAPE:',
#  'TZEVTY:',
#  'LESLIE:',
#  'NEWS REPORTER:',
#  'JADE DAVIS:',
#  'PERSON:',
#  'NEAL BRENNAN:',
#  'HOLLA:',
#  'VIDEO GUY:',
#  'CORY:',
#  'DAMIANO MARCHETTI:',
#  'MARC:',
#  'AREA:',
#  'SHUBHANGI:',
#  'YANGBIN:',
#  'PENNY:',
#  'TABITHA:',
#  'COUNCILMEMBER BRAD LANDER:',
#  'UCHTDORF:',
#  'KOHLHAGEN:',
#  'OKALEX BLUMBERG:',
#  'WORKER:',
#  'CARL DIGGLER:',
#  'MOE TUCKER:',
#  'MALE BRITISH VO:',
#  'CALEB:',
#  'MARK:',
#  'NAVIGATION:',
#  'TIM HOWARD:',
#  'ANTIFA SUPERSOLDIER UPDATE:',
#  'CORRECTION:',
#  'KELLY HERRON:',
#  'ISAAC GREEN:',
#  'HEWITT:',
#  'GRADY:',
#  'EDDIE:',
#  'ALEX BLUMBERG AND ALEX GOLDMAN:',
#  'KASHMIR HILL:',
#  'HARRY CHAPIN:',
#  'WILLIAM EDMUNDSON:',
#  'SARAH:',
#  'POPE BROCK:',
#  'CARTOON BEAR:',
#  'HOSTESS:',
#  'ALEXEY KOVALEV:',
#  'MAX SILVESTRI:',
#  'JESSICA YUNG:',
#  'MONTANA WOMAN:',
#  'MARC LESLIE GOLDMAN:',
#  'CROWD:',
#  'JAMIE KEILES:',
#  'TROY HUNT:',
#  'BERNIE:',
#  'GUESTS:',
#  'PRODUCER:',
#  'SUPERVISOR:',
#  'FATHER COUGHLIN:',
#  'ARCHIVAL:',
#  'PHOEBE:',
#  'UNOBTAINIUMTIM HOWARD:',
#  'SASAN:',
#  'GARY:',
#  'GREGORY SCHULZ:',
#  'AUTO VOICE:',
#  'JAMES BROWN:',
#  'KARA:',
#  'NATASHA TORRES:',
#  'RUKMINI :',
#  'SHIRLEY:',
#  'MEGAN:',
#  'DALY:',
#  'MIKE DALY:',
#  'KYLIE:',
#  'LUCIA:',
#  'FEMALE NEWSCASTER:',
#  'DALLAS:',
#  'NED THURMOND:',
#  'TONY:',
#  'JADE:',
#  'MATT MOLESKI:',
#  'HOPE:',
#  'BRIEN:',
#  'BLIPPI VIDEO:',
#  'JULIA:',
#  'MASON REESE:',
#  'SOPHIE:',
#  'GLUEBOY:',
#  'SOTHEAVY AT:',
#  'MAX:',
#  'ALEX QUILICI:',
#  'JASWINDER:',
#  'GUY:',
#  'SV:',
#  'ERIC SIN:',
#  'JORDAN PELTZ:',
#  'SP:',
#  'PUBLIC RELATIONS PROFESSIONAL:',
#  'ELLE:',
#  'ALANA:',
#  'PASSENGER:',
#  'RYAN GALLAGHER:',
#  'MAN BUILDING MINKA:',
#  'KATIE:',
#  'PHILIP:',
#  'ELDERLY WOMAN:',
#  'DALLAS MCLEAN:',
#  'JENNIFER BOULANGER:',
#  'CHLOE:',
#  'MOSHE KASHER:',
#  'PHIA BENIN:',
#  'FELIX BIEDERMAN:',
#  'TED:',
#  'SHULEM:',
#  'LYNN LEVY:',
#  'REESE:',
#  'PHONE:',
#  'MIKE:',
#  'EMZOTIC VIDEO:',
#  'NIKITA:',
#  'UCBALEX:',
#  'DPI HDTVPJ:',
#  'JANIE:',
#  'MATTHEW:',
#  'PAT:',
#  'BARACK OBAMA:',
#  'DAN:',
#  'STEPHANIE FOO:',
#  'MARC MANACH:',
#  'SUSAN BRACKNEY:',
#  'PEDRO SERRANO:',
#  'COUNCIL MEMBER LANDER:',
#  'CARRIAGE DRIVER:',
#  'ALLA:',
#  'KC:',
#  'YOUTUBER:',
#  'JODIE:',
#  'ALLY SHEEDY:',
#  'KALILA:',
#  'CHAIRPERSON VACCA:',
#  'BROTHER:',
#  'MELANIE ENSIGN:',
#  'PROTESTERS:',
#  'SRUTH:',
#  'NANCY WARREN:',
#  'DANIEL:',
#  'EVAN RATLIFF:',
#  'ERIC RABE:',
#  'ANNA:',
#  'ASHLEY:',
#  'ALEX BLUMBERG:',
#  'JON HANSEN:',
#  'STRIKETHROUGH:',
#  'NOAH:',
#  'JAMIL SMITH:',
#  'CINDY:',
#  'MARLIN:',
#  'RICK BELL:',
#  'HILARY:',
#  'SARAH JEONG:',
#  'SHULEM DEEN:',
#  'SAM:',
#  'HANS:',
#  'SARA VIKLOMERSON:',
#  'COMPUTER:',
#  'DM:',
#  'NEIGHBOR:',
#  'MATTHEW BRODERICK:',
#  'DAVID JONES:',
#  'CALLER:',
#  'CHARLIE VIDEO:',
#  'FOX AND FRIENDS MALE VOICE:',
#  'GRAD STUDENT:',
#  'VOICEOVER:',
#  'DALE:',
#  'MALE VOICE:',
#  'MEGAN CONLEY:',
#  'DREA PETERS:',
#  'ALEX JONES:',
#  'ALISA:',
#  'AARON LAMMER:',
#  'ROSS:',
#  'LMP:',
#  'CHARLEY:',
#  'FELIX:',
#  'MIKE :',
#  'HOST:',
#  'CHOIRE SICHA:',
#  'SHANE DAWSON:',
#  'NATE:',
#  'CALL CENTER GUY:',
#  'BILL COURTNEY:',
#  'AIRPLANE ANNOUNCEMENT:',
#  'RYAN:',
#  'MATT LITTLE:',
#  'ANNA FOLEY:',
#  'PAUL FORD:',
#  'SWAT:',
#  'GIRL RECORDING:',
#  'NEWS TAPE:',
#  'P:',
#  'TIM WOLFE:',
#  'ELIZABETH DWOSKIN:',
#  'MAYA WILEY:',
#  'KRISTEN:',
#  'JAMIL:',
#  'ANDREA FAVILE:',
#  'PROTESTOR:',
#  'KID:',
#  'ROBOT:',
#  'CONNOR:',
#  'AM:',
#  'ERIC:',
#  'VILLAIN:',
#  'CHLOE PRASINOS:',
#  'ERSZI:',
#  'SCARY AUDIO:',
#  'DAVID MAYNOR:',
#  'TJ:',
#  ':',
#  'BRINA:',
#  'ELLIOTT:',
#  'VOICE:',
#  'ALEX MARTIN:',
#  'MASON:',
#  'PENNY LANE:',
#  'AARON NIELSON:',
#  'BERNIE SANDERS:',
#  'JEN:',
#  'M PJ VOGT VIDEO:',
#  'AUTOMATED MALE VOICE:',
#  'ALBERTO:',
#  'HACKING TEAM ADVERTISEMENT:',
#  'STEPHANIE:',
#  'THE RIDDLER:',
#  'SASAN GOODARZI:',
#  'CARL ZIMMER:',
#  'JIMMY:',
#  'LISA SANDERS:',
#  'THREAT:',
#  'MATT BOWRON:',
#  'KEITH:',
#  'CHAIRPERSON JAMES VACCA:',
#  'PHIA AND PJ:',
#  'DENELLE:',
#  'BILL BURRINGTON:',
#  'NATHAN:',
#  'LINA:',
#  'AINSLEY EARHARDT:',
#  'MONTAGE:',
#  'AIRPORT ANNOUNCER:',
#  'PIKE LONG:',
#  'BARRY CRIMMINS:',
#  'SAMIN NOSRAT:',
#  'ATLANTA:',
#  'MATT SEGAL:',
#  'BRIAN:',
#  'MICK LAWLOR:',
#  'KIDS:',
#  'BRIGID:',
#  'DAMIANO MARCHETTIE:',
#  'ANTONIO GARCIA MARTINEZ:',
#  'RUSS FEINGOLD:',
#  'EDGAR:',
#  'CHRIS NEARY:',
#  'PATRICIA:',
#  'STEVE AUSTIN:',
#  'OTHER ALEX:',
#  'JENNI:',
#  'BENNY:',
#  'ALLI:',
#  'AMY GREEN:',
#  'MEL:',
#  'SUMMER ANNE BURTON:',
#  'MARY:',
#  'JOHN URQHART:',
#  'ALEXEY:',
#  'EMZOTIC:',
#  'D:',
#  'MICHAEL FERTIK:',
#  'JAMES DAMORE:',
#  'SARAH KOENIG:',
#  'TERRY GOU:',
#  'ELLIOT RODGER:',
#  'SHARKEISHA:',
#  'GRACE:',
#  'BILL REESE:',
#  'GENTLEMENGOLDMAN:',
#  'AL:',
#  'KNICKS FAN:',
#  'LEOPOLD:',
#  'LINDA:',
#  'MATT FARLEY:',
#  'JEFF FLAKE:',
#  'PEH:',
#  'SYLVIE DOUGLIS:',
#  'JENNIFER:',
#  'ANDREW:',
#  'SHEILA:',
#  'ROMAN:',
#  'LM:',
#  'ERIC BOLLING:',
#  'CS:',
#  'BURKMAN:',
#  'DAVE MAYNOR:',
#  'ALEX BACK ANNOUNCE:',
#  'DEVIN:',
#  'BRINKLEY:',
#  'ERROL:',
#  'TECHNICIAN:',
#  'SWENSON:',
#  'CAR DEALER:',
#  'LULU:',
#  'ETERNO:',
#  'JEAN:',
#  'OUT HERECARLOS:',
#  'DENELLE DIXON:',
#  'MARISSA:',
#  'PIKE:',
#  'ADAM WEST:',
#  'CHRIS MITCHELL:',
#  'CHOIRE:',
#  'DIANE WEIGLEY:',
#  'ANDREA:',
#  'LARRY TABAK:',
#  'BILLY:',
#  'RESIDENT:',
#  'ANTONIO:',
#  'KYLE:',
#  'LIL B:',
#  'JULIA ANGWIN:',
#  'PEDRO:',
#  'JIA TOLENTINO:',
#  'DAMINANO:',
#  'MACKENZIE:',
#  'PJPJ:',
#  'ERIC YEARWOOD:',
#  'SULEM:',
#  'COMCAST OPERATOR:',
#  'MELISSA:',
#  'MICK:',
#  'TOM VAN VLECK:',
#  'PAUL LE ROUX:',
#  'GODMAN:',
#  'TRUMP:',
#  'CHRIS COLIN:',
#  'BRONZSON:',
#  'MARIA ESPINOZA:',
#  'FAN:',
#  'KEVIN ROOSE:',
#  'BRITISH VOICE:',
#  'DIETER UCHTDORF:',
#  'KATIE NOTOPOULOS:',
#  'MATT KIME:',
#  'KATELYN:',
#  'KURT MELBY:',
#  'MACROFORM:',
#  'ROMAN MARS:',
#  'NEWS CLIPS OF OFFICERS YELLING:',
#  'SHINJIRO ONO:',
#  'SUMMER:',
#  'MALE CHARACTER:',
#  'AARON:',
#  'MARGOT SAUNDERS:',
#  'ANDERS:',
#  'INTERNATIONAL NEWS VIDEOS:',
#  'ARCHIVAL NEWS:',
#  'BARRY:',
#  'S MOM:',
#  'LAURA:',
#  'SRUTHI PINNAMANENI:',
#  'Q:',
#  'MAX LINSKY:',
#  'RIDESHARE DRIVER:',
#  'SCOTT PAGE:',
#  'NATHAN FOR YOU:',
#  'JEFFREE:',
#  'ALEX GOLDMAN AND PJ:',
#  'BEDLACK:',
#  'TV SOUND:',
#  'PHILIP BOWDEN:',
#  'SEB:',
#  'FEMALE VOICE:',
#  'ALEXIS:',
#  'PINNAMANENI:',
#  'IM PJ VOGTPJ:',
#  'JOHN ETERNO:',
#  'CYNTHIA:',
#  'JARED KNABENAUR:',
#  'EVAN:',
#  'RUKMINI CALLIMACHI:',
#  'GREG:',
#  'MARC GOLDMAN:',
#  'POLITICAL ANALYST:',
#  'REPRESENTATIVE LONG:',
#  'JEREMY:',
#  'JAMES:',
#  'IN SONG:',
#  'KORN:',
#  'JACK:',
#  'SHUBANGHI:',
#  'PJPJ VOGT:',
#  'RITCHIE:',
#  'FEMALE AUTOMATED VOICE:',
#  'MASTER SONG:',
#  'HILARY CLINTON:',
#  'BRUNO:',
#  'TAREN:',
#  'PEWDIEPIE:',
#  'BRENT:',
#  'VICTORIA:',
#  'CATHY:',
#  'TYLER VIDEO:',
#  'VIDEO WOMAN:',
#  'TANNER:',
#  'GOVERNMENT PERSON:',
#  'ANDERS SANDBERG:',
#  'CHRISTINA:',
#  'BUS DRIVER:',
#  'DONALD TRUMP:',
#  'DONNA:',
#  'HIGH SCHOOL FILM:',
#  'RECORDING:',
#  'RUNA SANDVIK:',
#  'CHIARA ATIK:',
#  'PJ VOGT:',
#  'HOWARD WALTZMAN:',
#  'HARVEY:',
#  'JON RONSON:',
#  'NEWS CLIP:',
#  'BRITTANY:',
#  'M:',
#  'KAREN:',
#  'JACOB:']

# %%
list(names_unique)[490:]
# Out:
# ['CHIARA ATIK:',
#  'PJ VOGT:',
#  'HOWARD WALTZMAN:',
#  'HARVEY:',
#  'JON RONSON:',
#  'NEWS CLIP:',
#  'BRITTANY:',
#  'M:',
#  'KAREN:',
#  'JACOB:',
#  'LAURA LEE:',
#  'PEOPLE IN BACKGROUND:',
#  'LULU MILLER:',
#  'CHRIS:',
#  'ALEX:',
#  'PJ:',
#  'MARCO RUBIO:',
#  'GENE:',
#  'S EMPLOYEE:',
#  'WOLF:',
#  'SEAN:',
#  'BILL:',
#  'EMILY KENNEDY:',
#  'NATHANIEL:',
#  'AB:',
#  'JOSHUA:',
#  'PAIGE:',
#  'ED:',
#  'YOUSSEF:',
#  'RHYMEFEST:',
#  'CAB DRIVER:',
#  'ADAM SINGOLDA:',
#  'BLIPPI:',
#  'BRITTNEY:',
#  'HAVN:',
#  'KYLIE OCHOA:',
#  'TED CRUZ:',
#  'ROBIN RADCLIFFE:',
#  'SMASH MOUTH:',
#  'LYNDON JOHNSON:',
#  'TOMMY LOFTUS:',
#  'YOUTUBE:',
#  'PJ AND SRUTHI:',
#  'MOSHE:',
#  'GREGORY:',
#  'LISA:',
#  'CAYDEN:',
#  'DAVID FREW:',
#  'NEWSCASTER:',
#  'HIGINIO OCHOA:',
#  'JOE:',
#  'LONNY:',
#  'TAYLOR VIDEO:',
#  'ERIC VALOR:',
#  'KASHMIR:',
#  'CLAY:',
#  'TRISHA:',
#  'MATT LIEBER:',
#  'MIKE DOUGLAS:',
#  'TAMMY:',
#  'SHARMA:',
#  'VLOGGER:',
#  'TPJ:',
#  'MELANIE:',
#  'POSTAL WORKER:',
#  'OFFICER:',
#  'MATTHEW KEYS:',
#  'JOSH MUMM:',
#  'PICKLES VIDEO:',
#  'MARIA:',
#  'EMILY:',
#  'SAL:',
#  'MICHAEL BAZZELL:',
#  'ISAAC:',
#  'PRESTON:',
#  'LOUIS:',
#  'ART:',
#  'WILL:',
#  'DAVID LETTERMAN:',
#  'DJ KHALED:',
#  'MISTRESS MORGAN:',
#  'AJ:',
#  'LARRY:',
#  'MILES:',
#  'COP RADIO:',
#  'BEN:',
#  'NELDA BUSS:',
#  'KALIA:',
#  'RACHAEL RAY:',
#  'JOHN DEHLIN:',
#  'ALIZA:',
#  'JEFF HOLM:',
#  'TROY:',
#  'CHRIS ADAMS:',
#  'DAVEY D:',
#  'MARTIN LEWIS:',
#  'TZVETY:',
#  'POLICE OFFICER:',
#  'CLIP:',
#  'PRESTON MARDENBOROUGH:',
#  'TRUSTEE:',
#  'JESSICA:',
#  'KELLY:',
#  'ADAM:',
#  'JASON PARHAM:',
#  'BARTENDER:',
#  'AG:',
#  'STEVE:',
#  'EDWIN:',
#  'JAMES DOLAN:',
#  'AINSLEY:',
#  'MELISSA MELENDEZ:',
#  'AV:',
#  'SISTER:',
#  'DIAMIANO:',
#  'WYATT:',
#  'OTWASKA:',
#  'ALAN PENNY:',
#  'MARGOT:',
#  'ANCHOR:',
#  'WILLIAM:',
#  'JOEL:',
#  'COP:',
#  'AMEEN:',
#  'CHIARA:',
#  'GOODWIN:',
#  'DARK DEN VIDEO:',
#  'DAN MCDERMOTT:',
#  'CLAUDIA:',
#  'OTHER MALE VOICE:',
#  'OBAMA:',
#  'CHARLIE:',
#  'WOLF BLITZER:',
#  'DAISY:',
#  'PROTESTORS:',
#  'DON SEIFORD:',
#  'PATRICIA LAKIN:',
#  'MELISSA MARK:',
#  'SEAN MCFARLANE:',
#  'FEMALE EMPLOYEE:',
#  'SHRUTI RAVINDRAN:',
#  'HELEN:',
#  'CHRIS TURNER:',
#  'DOUG:',
#  'GIRL:',
#  'TWO:',
#  'ELIZABETH:',
#  'SUNNY:',
#  'CO:',
#  'DANIEL BOTEANU:',
#  'GUEST:',
#  'BLANCA:',
#  'JOSEPH COX:',
#  'KIMBERLY:',
#  'UNKNOWN:',
#  'JOHN:',
#  'NORM:',
#  'JUSTIN:',
#  'SIVEIRA:',
#  'CHUCK GRASSLEY:',
#  'IRA GLASS:',
#  'JON ROSS:',
#  'INTERVIEWER:',
#  'TRICIA:',
#  'REPORTER:',
#  'JENNIFER JOHNSON:',
#  'JENNY:',
#  'JON:',
#  'PAUL:',
#  'MARISSA HERNANDEZ:',
#  'RICHARD BLUMBERG:',
#  'TIM JOHNSON:',
#  'SUZANNE:',
#  'JOHN HERRMAN:',
#  'BRIDGID:',
#  'TAMMY MARSHALL:',
#  'MARLIN JENSEN:',
#  'BILL ON INFOMERCIAL:',
#  'DONALD MODERATOR:',
#  'BILL DE BLASIO:',
#  'DENAT:',
#  'SUSAN:',
#  'VOICE ON VIDEO:',
#  'NEWS:',
#  'DREW:',
#  'JOSE:',
#  'MATT:',
#  'SCOTT:',
#  'TAVES:',
#  'PHONE RECORDING:',
#  'JOSIE COATESWORTH:',
#  'BOBBY ARCHER:',
#  'GOLDMAN:',
#  'ALEX GOLDMAN:',
#  'BOB MASTER:',
#  'S SON:',
#  'NEWS FOOTAGE:',
#  'NEW MALE VOICE:',
#  'NED:',
#  'MARY PREVITE:',
#  'LEECIA EVE:',
#  'ADRIAN ROSELLI:',
#  'JAMIE:',
#  'VIRGIL:',
#  'BRANDON GOOZMAN:',
#  'CHRISTINA :',
#  'NEDLA:',
#  'STEVE HUFFMAN:',
#  'TRAIN VOICEOVER:',
#  'WOMAN AND ALEX AND PJ:',
#  'BRAD:',
#  'REALITY:',
#  'CLAY JOHNSON:',
#  'SHINJIRO:',
#  'S VOICE:',
#  'LETTERMAN:',
#  'SRUTHI:',
#  'RICK:',
#  'DAMIANO:',
#  'MATT NELSON:',
#  'TAYLOR:',
#  'TV HOST:',
#  'JANIE HAMPTON:',
#  'HELEN NISSENBAUM:',
#  'NACOLE:',
#  'DAN AUSTIN:',
#  'CNN:',
#  'MORIEL IN TEL AVIV:',
#  'JOHN RYAN:',
#  'MAXIME:',
#  'KAREN DUFFIN:',
#  'HANSEN:',
#  'JOSH:',
#  'SELF DESTRUCT BUTTONPJ:',
#  'KEVIN SERVICE:',
#  'IN TAPE:',
#  'GENE DEMBY:',
#  'KARA SWANSON:',
#  'STEVEN CROWDER:',
#  'PJ AND KASHMIR:',
#  'ETHAN:',
#  'ZARDULU:',
#  'ELAINE:',
#  'LOLA:',
#  'PHIA BENNIN:',
#  'DAVE HIGGINS:',
#  'PJ AND ALEX:',
#  'CATY:',
#  'FRED:',
#  'MALE NEWSCASTER:',
#  'KYLE WALKER:',
#  'ALEX BLOOMBERG:',
#  'SWETA VIDEO:',
#  'ANNEMARIE:',
#  'ADAM DAVDISON:',
#  'NICK SAMBRATO:',
#  'BOTH:',
#  'SHIRLEY BRAHA:',
#  'THOMAS:',
#  'TOM:',
#  'BLAKE:',
#  'CHUCK JOHNSON:',
#  'JASON:',
#  'HARLEY:',
#  'HACKING TEAM ADVERTISMENT:',
#  'JASON SCOTT:',
#  'CHAIRMAN:',
#  'CATHERINE:',
#  'MALE VOICE AT DOCK:',
#  'MIKE MASNICK:',
#  'MICHAEL:',
#  'EMMA:',
#  'BRUNO TABBI:',
#  'JORGE JUST:',
#  'ARIEL:',
#  'TURBOTAX EMPLOYEE:',
#  'ADRIAN CHEN:',
#  'EDDIE WATKINS:',
#  'ETHAN ZUCKERMAN:',
#  'LUCIA MOSES:',
#  'DERAY:',
#  'KATIE OLDHAM:',
#  'DUDE:',
#  'SNIGDHA:',
#  'ANDRE:',
#  'ALIX:',
#  'NATALIA:',
#  'CLAUSEN:',
#  'NICK THOMAS:',
#  'FBI AGENT:',
#  'BARBARA:',
#  'DAVID:',
#  'JOEL REARDON:',
#  'EASTMAN:',
#  'ANNA SADOVNIKA:',
#  'SYLVIE:',
#  'CHRIS PRAIRIE:',
#  'SFX:',
#  'DB:',
#  'TUCKER CARLSON:',
#  'NIKOLAS:',
#  'RICHARD TURLEY:',
#  'FRIEND:',
#  'BRANDON:',
#  'LOGAN:',
#  'BOBBY:',
#  'AYA KATO:',
#  'PRAYER:',
#  'SECURITY GUARD:',
#  'JEAN COCO:',
#  'BRONZSON WOOD:',
#  'SOTHEAVY:',
#  'RUNA:',
#  'KORN SOKUN:',
#  'JOHN COLUCCI:',
#  'ERICA:',
#  'BRAD CARTER:',
#  'CROWDER:',
#  'C:',
#  'BOB:',
#  'ANSWERING MACHINE:',
#  'VINCENT FUSCA:',
#  'DYLAN:',
#  'AL WOLF:',
#  'MAV:',
#  'ROBIN:',
#  'BIANCA:',
#  'WOMAN:',
#  'CINDY DUNSTON QUIRK:',
#  'CARLA:',
#  'STRIKETHROUGH VIDEO:',
#  'PATTY ARMINE:',
#  'WORTHY:',
#  'MAN TALKING TO CROWD:',
#  'MATT HONAN:',
#  'KRIS:',
#  'PETER JENNINGS:',
#  'JOEL IN GAME:',
#  'PORTMAN:',
#  'CORREA:',
#  'ROMANA:',
#  'ALLI AND DYLAN:',
#  'MATT FARLEY SONG:',
#  'PAT ARMOR:',
#  'AUTUMN:',
#  'TOMAS:',
#  'OUTKEVIN:',
#  'HIGINIO:',
#  'CARLOS:',
#  'OTHER TRUSTEE:',
#  'DEGROOT:',
#  'HARRISON:',
#  'GALLAHER:',
#  'JEREMY GILLULA:',
#  'GOOGLEMAPS:',
#  'SCAMMER:',
#  'PETER:',
#  'LAURA DUCH:',
#  'CRUDO:',
#  'LINDSEY:',
#  'LYNN:',
#  'PJ AND ALEX GOLDMAN:',
#  'VIDEO VOICEOVER:',
#  'RECEPTIONIST:',
#  'TIM:',
#  'CHARITY WHYTE:',
#  'S FRIEND ERSZI:',
#  'DAVE:',
#  'JP:',
#  'LEECIA:',
#  'TRISTAN:',
#  'JONATHAN GOLDSTEIN:',
#  'PJ :',
#  'STEPHEN COLBERT:',
#  'TIM DAVIN:',
#  'KIM:',
#  'MINNIE:',
#  'DIANE:',
#  'CHRIS GILBERTI:',
#  'S DAD:',
#  'LUCY:',
#  'RYAN GREEN:',
#  'MACK:',
#  'LOGAN PAUL:',
#  'PSA:',
#  'LAUREN:',
#  'AUDIO RECORDING PLAYS:',
#  'TODD:',
#  'PHONE CALL:',
#  'NEWS ANCHORS:',
#  'ALE:',
#  'ERROL MORRIS:',
#  'SEAN CONNERY:',
#  'AMY:',
#  'STEVEN:',
#  'CHERYL:',
#  'AYA:',
#  'CORY DOCTOROW:',
#  'JANE MCGEHEE:',
#  'DREA:',
#  'KURT:',
#  'JONATHAN:',
#  'MATT LOGELIN:',
#  'MARTIN:',
#  'BLUMBERG:',
#  'S GUY:',
#  'RAJASHREE PINNAMANENI:',
#  'NEAL HORSLEY:',
#  'CALEY:',
#  'ANDREA ON TV:',
#  'HANNAH:',
#  'MICHELLE:',
#  'JANE:',
#  'SHANE:',
#  'CAROL:',
#  'DANIEL ALARCON:',
#  'RUKMINI:',
#  'RAFAEL CORREA:',
#  'FIOS AD:',
#  'LPC:',
#  'TRINITY:',
#  'ALBERTO MOEL:',
#  'NB:',
#  'RAY:',
#  'CHILDREN:',
#  'CHRISTINA LEE:',
#  'LEOPOLD PANDER:',
#  'JOHN SILVEIRA:',
#  'ADRIAN BATEMAN:',
#  'BRITTANY LUSE:',
#  'CYNTHIA AND SHEILA:',
#  'KEVIN:',
#  'ANNOUNCER:',
#  'STUDENT:',
#  'JACK MAPLE:',
#  'DAUGHTER:',
#  'RAY MCCONVILLE:',
#  'JEFF BATES:',
#  'GRANDMA:',
#  'JIM FADIMAN:',
#  'EDWIN RAYMOND:',
#  'JORGE:',
#  'JEFF:',
#  'LAURA LOOMER:',
#  'SAM NEARY:',
#  'MATT FURIE:',
#  'ERICA BRUNNER:',
#  'MAYA:',
#  'MOLLY:',
#  'CHARLES:',
#  'KIM CHERRY:',
#  'NEWSCLIP:',
#  'NP:',
#  'BRIAN HENDERSON:',
#  'CARLA GREEN:',
#  'KAMAL:',
#  'ALAN:',
#  'ASHLEY CLEEK:',
#  'MALE AUTOMATED VOICE:',
#  'LEAH:',
#  'ROXY:',
#  'AS:',
#  'BRITTNEY COOPER:',
#  'JM:',
#  'MIKE SABA:',
#  'GABRIEL ZAMORA:',
#  'AN:',
#  'CHARITY:',
#  'ELI:',
#  'SARA:',
#  'PATTY:',
#  'ANDREW KUKLEWICZ:',
#  'PODCAST:',
#  'THEM:',
#  'AL GARDNER:',
#  'HANS HERBERT JONNY MATTSSON:',
#  'HARVEY GOLDMAN:',
#  'TODD TAVES:',
#  'RORY:',
#  'PREET BHARARA:',
#  'HARRY:',
#  'WAITER:',
#  'CATHERINE RUSSELL:',
#  'BHATIA:',
#  'JOHN WAYNE:',
#  'DON:',
#  'ARI:',
#  'VIDEO:',
#  'TOM MADDEN:',
#  'BARBARA WALTERS:',
#  'MONIQUE:',
#  'RUBIO STAFF:',
#  'BRIAN WILLIAMS:',
#  'JASON MANTZOUKAS:',
#  'SINGOLDA:',
#  'BILL THOMAS :',
#  'VIDEO ANNOUNCER:',
#  'LIZZIE:',
#  'SHANNON:',
#  'ALIX SPIEGEL:',
#  'DISPATCHER:',
#  'NEWS ANCHOR:',
#  'MIKE MCDUFF:',
#  'PUA:',
#  'POSTSPJ:',
#  'DERAY MCKESSON:',
#  'NELDA:',
#  'CAT:',
#  'FEEST:',
#  'ALEX AND PJ:',
#  'KEITH CALDER:',
#  'DEEPAK:',
#  'BEN SHAPIRO:',
#  'CHARLEY EASTWOOD:',
#  'FLY:',
#  'TRUMP PHOENIX RALLY:',
#  'OKPJ:',
#  'REPRESENTATIVE BILLY LONG:',
#  'CALVIN:',
#  'ARMOR:',
#  'MAN:',
#  'PASSENGERS:',
#  'BATMAN:',
#  'BACKGROUND:',
#  'LEE:',
#  'SAMIRA:',
#  'BRAZILIAN ADS:',
#  'JOSIE:',
#  'JIM:',
#  'GLOBAL CHAOS RADIO:',
#  'PREET:',
#  'JUDE:',
#  'KAUFFMAN:']

# %%
aliases = {'PJ': ['DPI HDTVPJ:', 'PHONE RINGSPJ:', 'M PJ VOGT VIDEO:', 'PJPJ:', 'IM PJ VOGTPJ:', 'PJPJ VOGT:',
                       'PJ VOGT:', 'PJ:', 'PJ :', 'OKPJ:', 'POSTSPJ:', 'SELF DESTRUCT BUTTONPJ:', 'TPJ:'],
                 
           'Alex': ['ALEX:', 'AG:', 'GOLDMAN:', 'ALEX GOLDMAN:', 'GODMAN:', 'GENLTEMENGOLDMAN:']
                    }

# %% [markdown]
# ## Finalize documents for Mongo

# %%
for document in total_dictionaries:
    
    document['by_speaker']['PJ'] = ''
    document['by_speaker']['Alex'] = ''

    names = getName(document)
    quotes = getQuote(document)
    
    if len(names) == len(quotes):

        for index,name in enumerate(names):            
            if name in aliases['PJ']:
                document['by_speaker']['PJ'] += ' ' + quotes[index]

            elif name in aliases['Alex']:
                document['by_speaker']['Alex'] +=  ' ' + quotes[index]

    else:
        print(document['episodeID'])

# %% [markdown]
# ## Put data in MongoDB

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
db = client['replyall']

# %%
db.replyall.insert_many(total_dictionaries)

# %%
df = pd.DataFrame(db.replyall.find())

# %%
df.head()
# Out:
#                         _id  \
# 0  5d55ed03a18334a684f84834
# 1  5d55ed03a18334a684f84835
# 2  5d55ed03a18334a684f84836
# 3  5d55ed03a18334a684f84837
# 4  5d55ed03a18334a684f84838
#
#                                           by_speaker  \
# 0  {'PJ': '  Hey Alex.  You remember the other da...
# 1  {'PJ': '', 'Alex': '  From Gimlet this is Repl...
# 2  {'PJ': '  From Gimlet this is Reply All. I’m P...
# 3  {'PJ': '  From Gimlet, this is Reply All. I’m ...
# 4  {'PJ': '  From Gimlet, this is Reply All. I’m ...
#
#                                            episodeID  \
# 0         /shows/reply-all/xjhx3l/146-summer-hotline
# 1                 /shows/reply-all/rnhzlo/145-louder
# 2           /shows/reply-all/6nhgol/144-dark-pattern
# 3       /shows/reply-all/76hdrj/143-permanent-record
# 4  /shows/reply-all/gmhr36/142-we-didnt-start-the...
#
#                                           full_trans
# 0  PJ VOGT: Hey Alex.ALEX GOLDMAN: Hey PJ.PJ: You...
# 1  ALEX GOLDMAN: From Gimlet this is Reply All. I...
# 2  PJ VOGT: From Gimlet this is Reply All. I’m PJ...
# 3  [THEME MUSIC]PJ VOGT: From Gimlet, this is Rep...
# 4  [THEME MUSIC]PJ: From Gimlet, this is Reply Al...

# %%
df = pd.concat([df.drop(['by_speaker'], axis=1), df['by_speaker'].apply(pd.Series)], axis=1)

# %%
df.head()
# Out:
#                         _id  \
# 0  5d55ed03a18334a684f84834
# 1  5d55ed03a18334a684f84835
# 2  5d55ed03a18334a684f84836
# 3  5d55ed03a18334a684f84837
# 4  5d55ed03a18334a684f84838
#
#                                            episodeID  \
# 0         /shows/reply-all/xjhx3l/146-summer-hotline
# 1                 /shows/reply-all/rnhzlo/145-louder
# 2           /shows/reply-all/6nhgol/144-dark-pattern
# 3       /shows/reply-all/76hdrj/143-permanent-record
# 4  /shows/reply-all/gmhr36/142-we-didnt-start-the...
#
#                                           full_trans  \
# 0  PJ VOGT: Hey Alex.ALEX GOLDMAN: Hey PJ.PJ: You...
# 1  ALEX GOLDMAN: From Gimlet this is Reply All. I...
# 2  PJ VOGT: From Gimlet this is Reply All. I’m PJ...
# 3  [THEME MUSIC]PJ VOGT: From Gimlet, this is Rep...
# 4  [THEME MUSIC]PJ: From Gimlet, this is Reply Al...
#
#                                                   PJ  \
# 0    Hey Alex.  You remember the other day we tol...
# 1
# 2    From Gimlet this is Reply All. I’m PJ Vogt. ...
# 3    From Gimlet, this is Reply All. I’m PJ Vogt....
# 4    From Gimlet, this is Reply All. I’m PJ Vogt....
#
#                                                 Alex
# 0    Hey PJ.  I do remember that.  Alright.   Uh,...
# 1    From Gimlet this is Reply All. I’m Alex Gold...
# 2
# 3    And I’m Alex Goldman.  Hi Phia.  Oh.  (chuck...
# 4    And I’m Alex Goldman.  Welcome once again to...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 5 columns):
# _id           288 non-null object
# episodeID     288 non-null object
# full_trans    288 non-null object
# PJ            288 non-null object
# Alex          288 non-null object
# dtypes: object(5)
# memory usage: 11.3+ KB

# %% [markdown]
# ## Move to new workbook for NLP

# %%
import pickle

# %%
with open('df.pickle', 'wb') as to_write:
    pickle.dump(df, to_write)
